# %% [markdown]
# # Data Science Workshop
# # NBA Free Throws Prediction

# %% [markdown]
# ![title](img/free_throw_img.jpg)

# %% [markdown]
# In January 2015 a data-set of 600K NBA free-throws was upload to Kaggle by Sebastian-Mantey. The data was scraped from the website ESPN.com which belongs to an entertainment and sports programming network.
#
# Since the data-set was uploaded, 25 kernels were uploaded to Kaggle related to it. Most of the kernels summarize, analyze and visualize the data and do not try to predict anything. However, there are two interesting kernels:
#
# The kernel ‘Shooting percentage over time’, engages with the questions How does the Free Throw shooting percent develop over time? Does it go down as the game approaches the ending due to higher pressure? Does it go up thanks to players being warmer, or alternatively - better shooters take the ball?
#
# The findings of the analysis are that in the end of every quarter of a game, there is an increase in the number of free-throws and in the free-throws percentage. They also found that most of the throws in the end of every quarter were performed by better players, but still the absolute time of the throw affected the outcome more than how performed it.
#
# Another interesting kernel is ‘Pooling Partial Hierarchica via champs throw Free’, in which they try to find the best players in the data-set with statistical and probability methods such as complete pooling, and find the probability p for every player to succeed in the free-throw.
#
# Outside Kaggle, we found the article ‘Mindfulness and Free Throws’. This article investigate the relationship between mindfulness, preshot routine, and basketball free-throw percentage. The findings suggest that the combination of mindfulness levels, skill level (practice free-throw percentage), and competitive experience (year in school), all contribute to the prediction of competitive free throw percentage.

# %% [markdown]
# ## Data preparation and cleaning

# %% [markdown]
# ## Import Python Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Reading the Original Dataset

# %%
free_throws_db = pd.read_csv('free_throws.csv')
free_throws_db.drop_duplicates()
free_throws_db.head(10)
# Out:
#   end_result       game    game_id  period  \
# 0  106 - 114  PHX - LAL  261031013       1
# 1  106 - 114  PHX - LAL  261031013       1
# 2  106 - 114  PHX - LAL  261031013       1
# 3  106 - 114  PHX - LAL  261031013       1
# 4  106 - 114  PHX - LAL  261031013       1
# 5  106 - 114  PHX - LAL  261031013       1
# 6  106 - 114  PHX - LAL  261031013       1
# 7  106 - 114  PHX - LAL  261031013       2
# 8  106 - 114  PHX - LAL  261031013       2
# 9  106 - 114  PHX - LAL  261031013       2
#
#                                        play            player playoffs  \
# 0      Andrew Bynum makes free throw 1 of 2      Andrew Bynum  regular
# 1      Andrew Bynum makes free throw 2 of 2      Andrew Bynum  regular
# 2      Andrew Bynum makes free throw 1 of 2      Andrew Bynum  regular
# 3     Andrew Bynum misses free throw 2 of 2      Andrew Bynum  regular
# 4      Shawn Marion makes free throw 1 of 1      Shawn Marion  regular
# 5  Amare Stoudemire makes free throw 1 of 2  Amare Stoudemire  regular
# 6  Amare Stoudemire makes free throw 2 of 2  Amare Stoudemire  regular
# 7  Leandro Barbosa misses free throw 1 of 2   Leandro Barbosa  regular
# 8   Leandro Barbosa makes free throw 2 of 2   Leandro Barbosa  regular
# 9        Lamar Odom makes free throw 1 of 2        Lamar Odom  regular
#
#      score       season  shot_made   time
# 0    0 - 1  2006 - 2007          1  11:45
# 1    0 - 2  2006 - 2007          1  11:45
# 2   18-Dec  2006 - 2007          1   7:26
# 3   18-Dec  2006 - 2007          0   7:26
# 4   21-Dec  2006 - 2007          1   7:18
# 5  33 - 20  2006 - 2007          1   3:15
# 6  34 - 20  2006 - 2007          1   3:15
# 7  43 - 29  2006 - 2007          0  10:52
# 8  44 - 29  2006 - 2007          1  10:52
# 9  44 - 30  2006 - 2007          1  10:37

# %% [markdown]
# Describition of dataset:
# - end_result: host total score - guest total score
# - game: host team vs guest team
# - game_id: id of specific game
# - period: which quarter
# - play: who make free throw, make or miss free throw
# - player: player name
# - playoffs: whether a playoff game or regular game
# - score: host team score - guest team score at that time
# - season: NBA season
# - shot_made: whether player got the free throw
# - time: time left in that quarter

# %%
print("Number of free throws in database: %d"%(free_throws_db.shape[0]))
print("Number of games in database: {}".format(free_throws_db.game_id.unique().size))
print("Games distribution:")
free_throws_db['playoffs'].value_counts()
# Out:
# Number of free throws in database: 618019
# Number of games in database: 12874
# Games distribution:
# regular     575893
# playoffs     42126
# Name: playoffs, dtype: int64

# %% [markdown]
# ## Collecting more data from internet
#
# In order to expand our dataset, we decided to use an open source python library PandasBasketball, and use a webscrapper in order to get more players stats from https://www.basketball-reference.com website

# %% [markdown]
# Example of basketball-reference NBA player stats webpage:
# ![title](img/lebron_page_1.jpg)
# ![title](img/lebron_page_2.jpg)

# %% [markdown]
# And our code to extract from website html our data

# %%
from tools import get_player_stats
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='BeatifulSoup')
dataFrame = get_player_stats("Lebron James")
print(dataFrame.columns)
dataFrame.head(20)
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Height',
#        'Weight', 'ShootingHand', 'draftRank'],
#       dtype='object')
#      Season Age   Tm   Lg Pos     G    GS     MP     FG    FGA  ...   AST  \
# 0   2003-04  19  CLE  NBA  SG    79    79   3122    622   1492  ...   465
# 1   2004-05  20  CLE  NBA  SF    80    80   3388    795   1684  ...   577
# 2   2005-06  21  CLE  NBA  SF    79    79   3361    875   1823  ...   521
# 3   2006-07  22  CLE  NBA  SF    78    78   3190    772   1621  ...   470
# 4   2007-08  23  CLE  NBA  SF    75    74   3027    794   1642  ...   539
# 5   2008-09  24  CLE  NBA  SF    81    81   3054    789   1613  ...   587
# 6   2009-10  25  CLE  NBA  SF    76    76   2966    768   1528  ...   651
# 7   2010-11  26  MIA  NBA  SF    79    79   3063    758   1485  ...   554
# 8   2011-12  27  MIA  NBA  SF    62    62   2326    621   1169  ...   387
# 9   2012-13  28  MIA  NBA  PF    76    76   2877    765   1354  ...   551
# 10  2013-14  29  MIA  NBA  PF    77    77   2902    767   1353  ...   488
# 11  2014-15  30  CLE  NBA  SF    69    69   2493    624   1279  ...   511
# 12  2015-16  31  CLE  NBA  SF    76    76   2709    737   1416  ...   514
# 13  2016-17  32  CLE  NBA  SF    74    74   2794    736   1344  ...   646
# 14  2017-18  33  CLE  NBA  PF    82    82   3026    857   1580  ...   747
# 15  2018-19  34  LAL  NBA  SF    55    55   1937    558   1095  ...   454
# 16  2019-20  35  LAL  NBA  PG    37    37   1293    359    735  ...   397
# 17   Career           NBA      1235  1234  47528  12197  24213  ...  9059
#
#      STL  BLK   TOV    PF    PTS Height Weight ShootingHand draftRank
# 0    130   58   273   149   1654    206   113         Right         1
# 1    177   52   262   146   2175    206   113         Right         1
# 2    123   66   260   181   2478    206   113         Right         1
# 3    125   55   250   171   2132    206   113         Right         1
# 4    138   81   255   165   2250    206   113         Right         1
# 5    137   93   241   139   2304    206   113         Right         1
# 6    125   77   261   119   2258    206   113         Right         1
# 7    124   50   284   163   2111    206   113         Right         1
# 8    115   50   213    96   1683    206   113         Right         1
# 9    129   67   226   110   2036    206   113         Right         1
# 10   121   26   270   126   2089    206   113         Right         1
# 11   109   49   272   135   1743    206   113         Right         1
# 12   104   49   249   143   1920    206   113         Right         1
# 13    92   44   303   134   1954    206   113         Right         1
# 14   116   71   347   136   2251    206   113         Right         1
# 15    72   33   197    94   1505    206   113         Right         1
# 16    48   20   138    66    939    206   113         Right         1
# 17  1985  941  4301  2273  33482    206   113         Right         1
#
# [18 rows x 34 columns]

# %% [markdown]
# Columns used for this database for each player:
# - Position : The most common position for the player over his seasons.
# - FG%
# - 3P%
# - FT%
# - Height
# - Weight
# - ShootingHand
# - draftRank

# %% [markdown]
# ## We merged both the datasets according our collected data from internet.
# Some players stats had been inserted manually because some bugs found on PandasBasketball library

# %%
database_p1 = pd.read_csv("complete_database.csv")
database_p2 = pd.read_csv("complete_database_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
# Drop duplicated rows
database.drop_duplicates()
database.head(3)
# Out:
#   end_result       game    game_id  period  \
# 0  106 - 114  PHX - LAL  261031013       1
# 1  106 - 114  PHX - LAL  261031013       1
# 2  106 - 114  PHX - LAL  261031013       1
#
#                                    play        player playoffs  score  \
# 0  Andrew Bynum makes free throw 1 of 2  Andrew Bynum  regular  0 - 1
# 1  Andrew Bynum makes free throw 2 of 2  Andrew Bynum  regular  0 - 2
# 2  Andrew Bynum makes free throw 1 of 2  Andrew Bynum  regular  18-12
#
#         season  shot_made  ...    2P%    3P%       FT%  Height  Weight  \
# 0  2006 - 2007          1  ...  0.557  0.111  0.296296     213    129
# 1  2006 - 2007          1  ...  0.557  0.111  0.296296     213    129
# 2  2006 - 2007          1  ...  0.557  0.111  0.296296     213    129
#
#   draftRank Pos ShootingHand Team Difference
# 0        10   C        Right  LAL        1.0
# 1        10   C        Right  LAL        2.0
# 2        10   C        Right  LAL       -6.0
#
# [3 rows x 22 columns]

# %% [markdown]
# ## PrePrecessing the data
#
#
# ### Specifing Data Types

# %%
binary_variables = ['shot_made', 'playoffs', 'ShootingHand']
categorical_variables = ['end_result', 'game', 'game_id', 'period', 'play', 'player', 'season']
numeric_variables = ['score','time','FG%','2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank', 'Pos']

# %%
database.count()
# Out:
# end_result      617786
# game            617786
# game_id         617786
# period          617786
# play            617786
# player          617786
# playoffs        617786
# score           617786
# season          617786
# shot_made       617786
# time            617786
# FG%             617786
# 2P%             617786
# 3P%             612884
# FT%             570699
# Height          617786
# Weight          617786
# draftRank       617786
# Pos             617786
# ShootingHand    617786
# Team            617786
# Difference      617786
# dtype: int64

# %% [markdown]
# We can see, we have only two columns with missing data. First - the draftRank column.
# This values are missing because the players performed the free throw didn't have a draft rank and not because we couldn't collect the data. Second - 3P% has missing values since there are players that have never throws a 3-pointer.

# %% [markdown]
# ### processing the columns
# We will change the relevant categorical variable (only the position) to numeric and change the binary and numeric variables to be in the appropriate type.

# %%
# adding an abs_time column to our database:
database['minute'] = database.time.apply(lambda x: int(x[:len(x)-3]))
database['sec'] = database.time.apply(lambda x: int(x[len(x)-2:]))
database['abs_min'] = 12 - database['minute']+12*(database.period -1)
database['abs_time'] = 60*(database.abs_min-1) + 60 - database['sec']

# adding a scoreDif column that represents the difference in the groups scores in the time of the throw:
database['scores'] = database.score.replace(' - ', '-').apply(lambda x: x.split('-'))
database['scoreDif'] = database.scores.apply(lambda x: abs(int(x[1])-int(x[0])))

database.dtypes
# Out:
# end_result       object
# game             object
# game_id           int64
# period            int64
# play             object
# player           object
# playoffs         object
# score            object
# season           object
# shot_made         int64
# time             object
# FG%             float64
# 2P%             float64
# 3P%             float64
# FT%             float64
# Height           object
# Weight           object
# draftRank        object
# Pos              object
# ShootingHand     object
# Team             object
# Difference      float64
# minute            int64
# sec               int64
# abs_min           int64
# abs_time          int64
# scores           object
# scoreDif          int64
# dtype: object

# %% [markdown]
# ## Analyzing the data
#
#
# ### Analyzing the number of throws troughout the game
#
# We would like to show the free throws distribution throughout the game time,
# in our current dataset, the time column represents the time left in that quarter and the period column represents the quarter of the game, so we'll add a new column to our data which calculate the absolute time in the game that the throw was made.

# %%
#  counting the num of throws, and success throws precentage per minute
minutes = range(int(max(database.abs_min)))
total_throws = []
success_throws = []
success_precentage = []

def count_throws(database,minute):    
    made = len(database[(database.abs_min == minute) & (database.shot_made == 1)])
    success_throws.append(made)
    total = len(database[database.abs_min == minute])
    total_throws.append(total)
    if total == 0:
        precentage = 0.0
    else:
        precentage = made/total
    success_precentage.append(precentage)

for minute in minutes:
    count_throws(database,minute)

# %%
# Number of throws over time
plt.plot(minutes,total_throws)
plt.title('Number of throws over time')
plt.xlim([1,48])
plt.ylim([0, 40000])
plt.plot([12,12],[0,40000], '--', linewidth = 1, color = 'r')
plt.plot([24,24],[0,40000], '--', linewidth = 1, color = 'r')
plt.plot([36,36],[0,40000], '--', linewidth = 1, color = 'r')
plt.plot([48,48],[0,40000], '--', linewidth = 1, color = 'r')
plt.xlabel('Minute')
plt.ylabel('num of throws')
# Out:
# Text(0, 0.5, 'num of throws')

# %%
# Success throws precentage over time   
plt.plot(minutes,success_precentage)
plt.title('Scoring % over time - Always worse at the beginning')
plt.xlim([1,48])
plt.ylim([0.65,0.85])
plt.plot([12,12],[0,1], '--', linewidth = 1, color = 'r')
plt.plot([24,24],[0,1], '--', linewidth = 1, color = 'r')
plt.plot([36,36],[0,1], '--', linewidth = 1, color = 'r')
plt.plot([48,48],[0,1], '--', linewidth = 1, color = 'r')
plt.xlabel('Minute')
plt.ylabel('Free Throws %')
# Out:
# Text(0, 0.5, 'Free Throws %')

# %% [markdown]
# From the plots we can observe that at the begining of every querter, both the number of free throws and the success precentage drops.
# Moreover, at the end of a quarter, and especially at the end of the game, both plots increase.
# We can explain this behaivor, as basketball rules when a team made more than 5 fouls, every another foul made in that quarter will be penalty with a free throw.

# %% [markdown]
# ### Analyzing the number of throws troughout the game
# We want to see how the average of free throws attempted and succeed in games over our differents season in our dataset are distributed.

# %%
shot_attempted_per_game = database.groupby(["season", "playoffs"])['shot_made'].count().unstack()
shot_made_per_game = database.groupby(["season", "playoffs"])['shot_made'].sum().unstack()

# this has to be divided by the number of games for each season to get an average
number_of_games=database.groupby(["season", "playoffs"])['game_id'].nunique().unstack()

average_shot_made_per_game = shot_made_per_game/number_of_games
average_shot_attempted_per_game = shot_attempted_per_game/number_of_games


f, (ax1) = plt.subplots(figsize=(18,18))
first=average_shot_attempted_per_game.plot(ax=ax1, marker='o', figsize=(15,8), xticks=range(10), color=['b','r'], rot=90)
second=average_shot_made_per_game.plot(ax=ax1, marker='o', linestyle='--', figsize=(15,8), xticks=range(10), color=['b','r'], rot=90)
ax1.set_title('Average number of free throws per period. Attempted vs Successfula', size=25)
legend=plt.legend((' playoffs attempted','regular attempted','playoffs successful','regular successful'), loc=6)
ax1.add_artist(legend)
plt.show()

# %% [markdown]
# We can see that are not very big differences over the seasons at both attempted and successful shots.
# But there is a clear difference between the amount of made shots and and successful shots at playoffs and regular season.

# %%
made_shot_perc , missed_shot_perc = database['shot_made'].value_counts(normalize=True) * 100
print("Made shots percentage in dataset: %.2f"%(made_shot_perc))
print("Missed shots percentage in dataset: %.2f"%(missed_shot_perc))
# Out:
# Made shots percentage in dataset: 75.68
# Missed shots percentage in dataset: 24.32

# %% [markdown]
# ### The correlation between the player's draft rank and the free-throw result
#
# We wanted to check if there is a conection between the draft rank of the player performing the shot and the result of the shot.
# We have some missing values in the draftRank column, and it was because the player throwing had no draft rank, so we will fill the NAN cells with 61.

# %%
# Function that replace the field "undrafted" with a 0 in draftRank column

database['draftRank'] = database['draftRank'].replace(np.nan, 61)
database['draftRank'] = database['draftRank'].replace("undrafted", 61)
# pd.to_numeric(free_throws_db['draftRank'])
database['draftRank'] = database.draftRank.apply(lambda x: int(float(x)))

np.nanmax(database['draftRank'])

ranks = range(1, int(np.nanmax(database['draftRank']))+1)
success_precentage_by_rank = []

def throws_per_rank(database,rank):    
    total = len(database[database.draftRank == rank])
    if total == 0:
        precentage = 0.0
    else:
        made = len(database[(database.draftRank == rank) & (database.shot_made == 1)])
        precentage = made/total
    success_precentage_by_rank.append(precentage)

for rank in ranks:
    throws_per_rank(database,rank)

# %%
# Success throws precentage over time
plt.plot(list(ranks),success_precentage_by_rank)
plt.title('Success Throws percentage as function of Draft Rank  ')
plt.ylim([0,1])
plt.xlabel('Draft Rank')
plt.ylabel('Free Throws %')
# Out:
# Text(0, 0.5, 'Free Throws %')

# %% [markdown]
# As we see, there is no special trend in the graph (the FT% is between 0.7 to 0.9 for all ranks). We expected that the higher-ranked players would have better performence but we can't conclude it from the data.
#
# We have to take under consideration that the draft-rank data is not uniformly distributed, as we can see in the graph below, and is biased towared small values (the value 0 represents missing values, and in our case players who had no draft rank), so the barplot above needs to be normalized.

# %%
sns.distplot(database['draftRank'])

# %% [markdown]
# ### The correlation between the score difference and the free-throw result
#
# We will add a column calculating the differance.
# We assume that if the difference is small in the time of the shot, the player would be more stressed and his shooting precentage would drop.

# %%
difs = range(int(np.min(database['scoreDif']))+1,int(np.max(database['scoreDif']))+1)
success_precentage_by_scoreDif = []

def throws_per_dif(database,dif):    
    total = len(database[database.scoreDif == dif])
    if total == 0:
        precentage = 0.0
    else:
        made = len(database[(database.scoreDif == dif) & (database.shot_made == 1)])
        precentage = made/total
    success_precentage_by_scoreDif.append(precentage)

for dif in difs:
    throws_per_dif(database,dif)

# %%
# Success throws precentage over time
plt.bar(list(difs),success_precentage_by_scoreDif)
plt.title('Success Throws percentage as function of Score Difference')
plt.ylim([0,1])
plt.xlabel('Score Difference')
plt.ylabel('Free Throws %')
plt.show()
plt.bar(list(difs),success_precentage_by_scoreDif)
plt.title('Success Throws percentage as function of Score Difference')
plt.ylim([0,1])
plt.xlabel('Score Difference')
plt.ylabel('Free Throws %')
plt.xlim(0,15)
# Out:
# (0, 15)

# %% [markdown]
# At the 'Success Throws percentage as function of Score Difference' plot, it seems that our hypotesis that as long as the score difference gets bigger, so as the free-throw success precentaege is partly true.
# We can see a trend in the graph but it is not continuous.

# %% [markdown]
# ### The correlation between the player position and the free-throw result
# We want to analyze if the "Position" feature of each player could be a helpful feature that may help our prediction model.
# Above we can see a plot showing the distribution of the FT% over the different positions.

# %%
ax2 = sns.catplot(x="Pos", y="FT%", data=database);
#ax2 = sns.catplot(x="Pos", y="FT%",  kind="swarm", data=database);
ax2.set(xlabel='Player Position', ylabel='Throws Percentage')
plt.show()

# %%
# Find correlation between all variables
from preProcess import find_correlations
find_correlations(database)

# %% [markdown]
# Average FT% at each position

# %%
database.groupby('Pos').agg({'FT%':'mean'})
# Out:
#           FT%
# Pos
# C    0.664836
# PF   0.720946
# PG   0.795977
# SF   0.770927
# SG   0.795559

# %% [markdown]
# We can see that Centers players owns the worst percentage.
#
# Point Guards and Shouting Guards players holds the best percentage over all the positions.

# %% [markdown]
# Next, we will check how well our dataset represents the general population of NBA Players.
# 1. MSE of the FT% players achieved in their carrers and their FT% we have in the dataset.

# %% [markdown]
# ### Our goal
# We’ll try to explore two options for prediction:
#
# •	Offline prediction: try to predict the players succes percentage (for all kinds of throws) for the current season based on his past performance and give the coach an insight about the player.
#
# •	Online prediction : try to predict whether a player will hit in a certain throw.
#
# ### What's next?
#
# - Extract more statistical analysis on our current data, find corralation between more than two parameters.
# - Pre-process our data in order to create an initial ML model.
# - Achieve good results on our ML model
# - Try to reduce our problem dimension/features by analyzing which features have big influence.
# - "Engineer" more strong features in order to achieve dimension reduction.
# - Build new ML model and achieve good results, again! YEY!
# - Explain our ML model results, when it fails and why

# %% [markdown]
#  ### Fitting a model
#
#  We will choose the relevant columns (ommiting most of the categorical variables) from our model_database

# %%
# changing the position variable from categorial variable to numeric variable:
from preProcess import preProcess_position

# Keep small database with original FT%
db_for_baseline_model = database[["FT%","shot_made"]]

# changing the playoff and ShootingHand to binary variables:
database['playoffs'] = database['playoffs'].map(lambda x : 0 if x == 'regular' else 1)
database['ShootingHand'] = database['ShootingHand'].map(lambda x : 0 if x == 'Right' else 1)

# modify the numeric variables Height and Weight:
database['Height'] = database['Height'].map(lambda x : int(x))
database['Weight'] = database['Weight'].map(lambda x : int(x))

# %%
database.isnull().sum().sum()
# Out:
# 51989

# %%
# as we saw earlier, we have missing data in the 'FT%' and the '3P%' columns so we will fill the NA cells with the mode of the column
database['FT%'] = database['FT%'].fillna(database['FT%'].mode()[0])
database['3P%'] = database['3P%'].fillna(database['FT%'].mode()[0])

brian_db = database.copy()


database = preProcess_position(database)

database.columns

# %%
# we choose the relevant variables for our model:
continuous_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference']
binary_database = pd.DataFrame(database[binary_variables])
database[continuous_parameters].describe()
# Out:
#                  FG%            2P%            3P%            FT%  \
# count  617786.000000  617786.000000  617786.000000  617786.000000
# mean        0.463961       0.489447       0.297221       0.742858
# std         0.047091       0.039687       0.117763       0.091483
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.433000       0.466000       0.279000       0.682927
# 50%         0.452000       0.482000       0.335000       0.760000
# 75%         0.493000       0.510000       0.366000       0.804384
# max         0.672000       0.681000       1.000000       1.000000
#
#               Height         Weight      draftRank        abs_min  \
# count  617786.000000  617786.000000  617786.000000  617786.000000
# mean      200.689611     101.170698      19.872399      27.865444
# std         9.107146      12.606636      17.926089      14.121174
# min       165.000000      61.000000       1.000000       1.000000
# 25%       193.000000      92.000000       5.000000      16.000000
# 50%       203.000000     100.000000      14.000000      29.000000
# 75%       208.000000     111.000000      29.000000      40.000000
# max       229.000000     147.000000      61.000000      96.000000
#
#           Difference
# count  617786.000000
# mean        0.411400
# std        10.747354
# min       -63.000000
# 25%        -6.000000
# 50%         1.000000
# 75%         7.000000
# max        59.000000

# %% [markdown]
# For our model, we assume that our variables are normally distributed.
# We will examine this hypothesis and normalize the variables
#
# We'll plot the distribution plot of the variables 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference'
# (in 3 different plots because of the scale diffrence) :

# %%
sns.distplot(database['FG%'], color = 'red', label = "FG%") 
sns.distplot(database['2P%'], color = 'green', label = "2P%") 
sns.distplot(database['3P%'], color = 'orange', label = "3P%") 
sns.distplot(database['FT%'], color = 'blue', label = "FT%") 
plt.legend()

# %%
sns.distplot(database['Weight'], color = 'orange', label = "Weight [kgs]") 
sns.distplot(database['Height'], color = 'blue', label = "Height [cms]")
plt.legend()

# %%
sns.distplot(database['Difference'], color = 'blue')

# %% [markdown]
# we can see that the variables are distribute close no normal.
# we'll normalise these colunms so that the mean would be 0 and the variance would be 1:

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
database[semiNormal_parameters] = sc.fit_transform(database[semiNormal_parameters])

# %%
sns.distplot(database['FG%'], color = 'red') 
sns.distplot(database['2P%'], color = 'green') 
sns.distplot(database['FT%'], color = 'blue') 
sns.distplot(database['3P%'], color = 'orange') 
plt.legend(labels=['FG% distribution', '2P% distribution', 'FT% distribution', '3P% distribution'])
plt.show()

# %%
sns.distplot(database['Weight'], color = 'orange') 
sns.distplot(database['Height'], color = 'blue') 
plt.legend(labels=['Weight distribution', 'Height distribution'])
plt.show()

# %%
sns.distplot(database['Difference'], color = 'blue') 
plt.legend(labels=['Difference distribution'])
plt.show()

# %% [markdown]
# In all the variables above, we got mean close to 0 and std 1.
#
# The variables 'abs_time' and 'draftRank' , doesn't distribute semi-normal, so we will normalize them using min-max normalization:

# %%
sns.distplot(database['abs_min'], color = 'blue', label = 'abs_min distribution') 
sns.distplot(database['draftRank'], color = 'red', label = 'draftRank distribution') 
plt.legend(labels=['abs_time distribution','draftRank distribution'])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()

nonNormal_parameters = ['abs_min', 'draftRank']
database[nonNormal_parameters] = mm.fit_transform(database[nonNormal_parameters])

# %%
sns.distplot(database['abs_min'], color = 'blue', label = 'abs_min distribution') 
sns.distplot(database['draftRank'], color = 'red', label = 'draftRank distribution') 
plt.legend(labels=['abs_time distribution','draftRank distribution'])
plt.show()

# %%
model_parameters = ['player','playoffs', 'Pos', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
model_database = database[model_parameters]
model_database.describe()
# Out:
#             playoffs            Pos   ShootingHand           FG%  \
# count  617786.000000  617786.000000  617786.000000  6.177860e+05
# mean        0.068179       0.555441       0.093804  1.488746e-16
# std         0.252053       0.224102       0.291557  1.000001e+00
# min         0.000000       0.200000       0.000000 -9.852348e+00
# 25%         0.000000       0.500000       0.000000 -6.574712e-01
# 50%         0.000000       0.500000       0.000000 -2.540008e-01
# 75%         0.000000       0.800000       0.000000  6.166458e-01
# max         1.000000       0.800000       1.000000  4.417761e+00
#
#                 2P%           3P%           FT%        Height        Weight  \
# count  6.177860e+05  6.177860e+05  6.177860e+05  6.177860e+05  6.177860e+05
# mean   6.618571e-15 -4.404591e-16 -8.296677e-16 -1.135882e-15 -1.406626e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.233280e+01 -2.523898e+00 -8.120213e+00 -3.918861e+00 -3.186475e+00
# 25%   -5.907943e-01 -1.547287e-01 -6.551090e-01 -8.443498e-01 -7.274507e-01
# 50%   -1.876352e-01  3.208035e-01  1.873812e-01  2.536899e-01 -9.286373e-02
# 75%    5.178932e-01  5.840446e-01  6.725500e-01  8.027098e-01  7.796933e-01
# max    4.826656e+00  5.967749e+00  2.810832e+00  3.108593e+00  3.635335e+00
#
#            draftRank        abs_min    Difference      shot_made
# count  617786.000000  617786.000000  6.177860e+05  617786.000000
# mean        0.314540       0.282794 -7.222903e-18       0.756780
# std         0.298768       0.148644  1.000001e+00       0.429027
# min         0.000000       0.000000 -5.900192e+00       0.000000
# 25%         0.066667       0.157895 -5.965566e-01       1.000000
# 50%         0.216667       0.294737  5.476704e-02       1.000000
# 75%         0.466667       0.410526  6.130444e-01       1.000000
# max         1.000000       1.000000  5.451449e+00       1.000000

# %%
model_database.head(5)
# Out:
#          player  playoffs  Pos  ShootingHand       FG%       2P%       3P%  \
# 0  Andrew Bynum         0  0.2             0  1.954469  1.702173 -1.581325
# 1  Andrew Bynum         0  0.2             0  1.954469  1.702173 -1.581325
# 2  Andrew Bynum         0  0.2             0  1.954469  1.702173 -1.581325
# 3  Andrew Bynum         0  0.2             0  1.954469  1.702173 -1.581325
# 4  Shawn Marion         0  0.5             0  0.425528  0.593486  0.286837
#
#         FT%    Height    Weight  draftRank   abs_min  Difference  shot_made
# 0 -4.881385  1.351730  2.207514   0.150000  0.000000    0.054767          1
# 1 -4.881385  1.351730  2.207514   0.150000  0.000000    0.147813          1
# 2 -4.881385  1.351730  2.207514   0.150000  0.042105   -0.596557          1
# 3 -4.881385  1.351730  2.207514   0.150000  0.042105   -0.596557          0
# 4  0.984793  0.034082 -0.172187   0.133333  0.042105    0.799137          1

# %% [markdown]
# ## Baseline Model
# Predicit free-throw success only with FT% feature. No learning process or algorithm is used here.
# Threshold classificator, FT% over 0.5 will be predicted as 1, else 0.

# %%
## Baseline model
from sklearn import metrics

baseline_predict = db_for_baseline_model["FT%"].apply(lambda x: 1 if x>=0.5 else 0)
expected = database.shot_made
print(metrics.classification_report(expected, baseline_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.12      0.18    150258
#            1       0.76      0.92      0.83    467528
#
#     accuracy                           0.72    617786
#    macro avg       0.54      0.52      0.50    617786
# weighted avg       0.66      0.72      0.67    617786

# %% [markdown]
# ## Logisitic Regression

# %%
v = model_database.player.value_counts()
log_reg_database = model_database[model_database.player.isin(v.index[v.gt(200)])] ## leave only players with more than 200 games.

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
v = model_database.player.value_counts()
log_reg_database = model_database[model_database.player.isin(v.index[v.gt(200)])] ## leave only players with more than 200 games.
logreg = linear_model.LogisticRegression(C=1e5)
Y = log_reg_database['shot_made']
X = log_reg_database.drop(columns=['shot_made','player'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

logreg.fit(X_train.values, y_train.values)
predictions = logreg.predict(X_test.values)
predicted_probs = logreg.predict_proba(X_test.values)

print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.03      0.06     46308
#            1       0.76      0.99      0.86    146877
#
#     accuracy                           0.76    193185
#    macro avg       0.65      0.51      0.46    193185
# weighted avg       0.71      0.76      0.67    193185

# %% [markdown]
# ## Linear SVM Model

# %%
from sklearn.model_selection import train_test_split

v = model_database.player.value_counts()
linear_svm_database = model_database[model_database.player.isin(v.index[v.gt(200)])] ## leave only players with more than 200 games.
#linear_svm_database = linear_svm_database.loc[linear_svm_database['player'] == 'LeBron James']
linear_svm_database = linear_svm_database
Y = linear_svm_database['shot_made']
X = linear_svm_database.drop(columns=['shot_made','player'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
# ## Linear SVM Model
# from sklearn.svm import SVC
# print(X_train.shape)
# input('hi')
# linear_svm_model = SVC(kernel='linear', class_weight='balanced',verbose=True,C=1)
# linear_svm_model.fit(X_train.values, y_train.values)
# print("Training DONE!")
# predictions = linear_svm_model.predict(X_test.values)
# print(metrics.classification_report(y_test, predictions))

# %%
from preProcess import run_PCA, find_correlations,detect_and_remove_outliers
from models import logreg
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics

v = model_database.player.value_counts()
log_reg_database = model_database[model_database.player.isin(v.index[v.gt(200)])] ## leave only players with more than 200 games.
Y = log_reg_database['shot_made']
X = log_reg_database.drop(columns=['shot_made','player'])
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
number_of_components = 2
X_train, X_test = run_PCA(X_train, X_test,number_of_components)

print(logreg(X_train, Y_train,X_test, Y_test))
# Out:
# Using TensorFlow backend.
#               precision    recall  f1-score   support
#
#            0       0.55      0.01      0.02     46308
#            1       0.76      1.00      0.86    146877
#
#     accuracy                           0.76    193185
#    macro avg       0.66      0.50      0.44    193185
# weighted avg       0.71      0.76      0.66    193185

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

v = brian_db.player.value_counts()
brian_db = brian_db[brian_db.player.isin(v.index[v.gt(200)])]
mm = MinMaxScaler()
sc = StandardScaler()
nonNormal_parameters = ['abs_min', 'draftRank']
semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
#brian_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(brian_db[semiNormal_parameters+nonNormal_parameters]) 
brian_db.player.value_counts()
brian_db.columns
onehot_pos_col = pd.get_dummies(brian_db['Pos'],prefix='Pos')
brian_db = pd.concat([brian_db,onehot_pos_col],axis=1)
brian_db = brian_db.drop(columns=['Pos'])
brian_db.columns
# Out:
# Index(['end_result', 'game', 'game_id', 'period', 'play', 'player', 'playoffs',
#        'score', 'season', 'shot_made', 'time', 'FG%', '2P%', '3P%', 'FT%',
#        'Height', 'Weight', 'draftRank', 'ShootingHand', 'Team', 'Difference',
#        'minute', 'sec', 'abs_min', 'abs_time', 'scores', 'scoreDif', 'Pos_C',
#        'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')

# %%
model_parameters = ['player','playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
brian_db = brian_db[model_parameters]
brian_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(brian_db[semiNormal_parameters+nonNormal_parameters])

# %%
from keras import backend as K
import tensorflow as tf
# Define our custom loss function
def focal_loss(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.utils import to_categorical
from keras.optimizers import Adagrad
Y = brian_db['shot_made']
X = brian_db.drop(columns=['shot_made','player'])#,"ShootingHand","FG%","2P%","3P%","Height","Weight","draftRank","Pos"])
print(X.shape)
print(X.columns)

X,_ = run_PCA(X,X,8)

model2 = Sequential()
model2.add(Dense(12, input_dim=8))
model2.add(LeakyReLU(alpha=0.1))
model2.add(Dense(20))#, activation='relu'))
model2.add(LeakyReLU(alpha=0.1))
model2.add(Dropout(0.5))
model2.add(Dense(10))#, activation='relu'))
model2.add(LeakyReLU(alpha=0.1))
model2.add(Dropout(0.5))
model2.add(Dense(5))#, activation='relu'))
model2.add(LeakyReLU(alpha=0.1))
model2.add(Dense(1, activation='sigmoid'))

from collections import Counter
print(sorted(Counter(Y).items()))
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
ros = RandomOverSampler(random_state=0)
#X_resampled, y_resampled = SMOTE().fit_resample(X, Y)
print(sorted(Counter(y_resampled).items()))

model2.compile(loss=[focal_loss], optimizer=Adagrad(learning_rate=0.001), metrics=['accuracy'])
history = model2.fit(X, Y, epochs=100, batch_size=256, class_weight={0:0.7, 1:0.3})
# Out:
# (585409, 16)
# Index(['playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG',
#        'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight',
#        'draftRank', 'abs_min', 'Difference'],
#       dtype='object')
# [(0, 140596), (1, 444813)]
# [(0, 444813), (1, 444813)]
# Epoch 1/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 17.0806 - accuracy: 0.5373
# Epoch 2/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.4990 - accuracy: 0.6224
# Epoch 3/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.4045 - accuracy: 0.6463
# Epoch 4/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.3612 - accuracy: 0.6578
# Epoch 5/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.3499 - accuracy: 0.6653
# Epoch 6/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.3282 - accuracy: 0.6694
# Epoch 7/100
# 585409/585409 [==============================] - 3s 5us/step - loss: 16.3139 - accuracy: 0.6730
# Epoch 8/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2943 - accuracy: 0.6764
# Epoch 9/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2940 - accuracy: 0.6785
# Epoch 10/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2904 - accuracy: 0.6799
# Epoch 11/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2791 - accuracy: 0.6817A: 1s - loss: 16.
# Epoch 12/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.2714 - accuracy: 0.6835A: 1s - l
# Epoch 13/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.2660 - accuracy: 0.6846
# Epoch 14/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2645 - accuracy: 0.6854
# Epoch 15/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2567 - accuracy: 0.6863
# Epoch 16/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2529 - accuracy: 0.6869
# Epoch 17/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2481 - accuracy: 0.6876
# Epoch 18/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.2414 - accuracy: 0.6881
# Epoch 19/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2396 - accuracy: 0.6891
# Epoch 20/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2351 - accuracy: 0.6896
# Epoch 21/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2344 - accuracy: 0.6900
# Epoch 22/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2303 - accuracy: 0.6902
# Epoch 23/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2272 - accuracy: 0.6905
# Epoch 24/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.2273 - accuracy: 0.6906
# Epoch 25/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.2244 - accuracy: 0.6899
# Epoch 26/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2147 - accuracy: 0.6912
# Epoch 27/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2199 - accuracy: 0.6907
# Epoch 28/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2105 - accuracy: 0.6906
# Epoch 29/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2107 - accuracy: 0.6913
# Epoch 30/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2051 - accuracy: 0.6914
# Epoch 31/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.2074 - accuracy: 0.6913
# Epoch 32/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2036 - accuracy: 0.6911
# Epoch 33/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2044 - accuracy: 0.6910
# Epoch 34/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1983 - accuracy: 0.6907
# Epoch 35/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.2025 - accuracy: 0.6907
# Epoch 36/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1972 - accuracy: 0.6904
# Epoch 37/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1918 - accuracy: 0.6901
# Epoch 38/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1887 - accuracy: 0.6908
# Epoch 39/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1871 - accuracy: 0.6894
# Epoch 40/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1887 - accuracy: 0.6902
# Epoch 41/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1875 - accuracy: 0.6899
# Epoch 42/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1846 - accuracy: 0.6893
# Epoch 43/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1792 - accuracy: 0.6894
# Epoch 44/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1819 - accuracy: 0.6892A: 1s - los
# Epoch 45/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1775 - accuracy: 0.6890
# Epoch 46/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1778 - accuracy: 0.6889
# Epoch 47/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1740 - accuracy: 0.6886
# Epoch 48/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1747 - accuracy: 0.6883
# Epoch 49/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1693 - accuracy: 0.6884
# Epoch 50/100
# 585409/585409 [==============================] - 5s 8us/step - loss: 16.1711 - accuracy: 0.6883
# Epoch 51/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1704 - accuracy: 0.6878A: 2s -
# Epoch 52/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1645 - accuracy: 0.6875
# Epoch 53/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1695 - accuracy: 0.6868
# Epoch 54/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1634 - accuracy: 0.6873
# Epoch 55/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1604 - accuracy: 0.6873A: 0s - loss: 16.1511 - ac
# Epoch 56/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1605 - accuracy: 0.6869
# Epoch 57/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1593 - accuracy: 0.6869
# Epoch 58/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1583 - accuracy: 0.6859
# Epoch 59/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1574 - accuracy: 0.6865
# Epoch 60/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1535 - accuracy: 0.6859
# Epoch 61/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1514 - accuracy: 0.6855
# Epoch 62/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1518 - accuracy: 0.6845
# Epoch 63/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1495 - accuracy: 0.6844
# Epoch 64/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1499 - accuracy: 0.6848
# Epoch 65/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1482 - accuracy: 0.6836
# Epoch 66/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1463 - accuracy: 0.6846
# Epoch 67/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1443 - accuracy: 0.6846
# Epoch 68/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1461 - accuracy: 0.6838
# Epoch 69/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1436 - accuracy: 0.6840
# Epoch 70/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1395 - accuracy: 0.6834
# Epoch 71/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1395 - accuracy: 0.6834
# Epoch 72/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1408 - accuracy: 0.6830
# Epoch 73/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1361 - accuracy: 0.6826
# Epoch 74/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1293 - accuracy: 0.6827
# Epoch 75/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1334 - accuracy: 0.6821
# Epoch 76/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1272 - accuracy: 0.6822
# Epoch 77/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1323 - accuracy: 0.6815
# Epoch 78/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1297 - accuracy: 0.6812
# Epoch 79/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1303 - accuracy: 0.6809
# Epoch 80/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1258 - accuracy: 0.6802
# Epoch 81/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1261 - accuracy: 0.6801
# Epoch 82/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1230 - accuracy: 0.6796
# Epoch 83/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1244 - accuracy: 0.6797
# Epoch 84/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1208 - accuracy: 0.6799
# Epoch 85/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1235 - accuracy: 0.6797A
# Epoch 86/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1269 - accuracy: 0.6788
# Epoch 87/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1199 - accuracy: 0.6791
# Epoch 88/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1212 - accuracy: 0.6786
# Epoch 89/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1172 - accuracy: 0.6791
# Epoch 90/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1218 - accuracy: 0.6782A: 0s - loss: 16.1218 - accuracy: 0.678
# Epoch 91/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1153 - accuracy: 0.6785
# Epoch 92/100
# 585409/585409 [==============================] - 4s 6us/step - loss: 16.1139 - accuracy: 0.6782
# Epoch 93/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1136 - accuracy: 0.6781
# Epoch 94/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1132 - accuracy: 0.6773
# Epoch 95/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1118 - accuracy: 0.6779A: 0s - loss: 16.1175 - accuracy: 0.67
# Epoch 96/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1098 - accuracy: 0.6773
# Epoch 97/100
# 585409/585409 [==============================] - 3s 6us/step - loss: 16.1052 - accuracy: 0.6774
# Epoch 98/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1090 - accuracy: 0.6764
# Epoch 99/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1098 - accuracy: 0.6765
# Epoch 100/100
# 585409/585409 [==============================] - 4s 7us/step - loss: 16.1078 - accuracy: 0.6764

# %%
from sklearn import metrics


print(metrics.classification_report(Y, np.round(model2.predict(X))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.25      0.30    140596
#            1       0.79      0.88      0.83    444813
#
#     accuracy                           0.72    585409
#    macro avg       0.59      0.56      0.56    585409
# weighted avg       0.69      0.72      0.70    585409

# %% [markdown]
# ### Neural Net - FOCAL LOSS
# - Drop NAN
# - Position one-hod encoded
# -  All features standarted to mean=0, std=1
# - Removing Outliers

# %%
database_p1 = pd.read_csv("database_preprocessed_part2.csv")
database_p2 = pd.read_csv("database_preprocessed_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
database = database.dropna()

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from preProcess import detect_and_remove_outliers

v = database.player.value_counts()
model_db = database[database.player.isin(v.index[v.gt(200)])]
mm = MinMaxScaler()
sc = StandardScaler()
nonNormal_parameters = ['abs_min', 'draftRank']
semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
onehot_pos_col = pd.get_dummies(model_db['Pos'],prefix='Pos')
model_db = pd.concat([model_db,onehot_pos_col],axis=1)
model_db = model_db.drop(columns=['Pos'])
print(model_db.columns)
model_parameters = ['player','playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
model_db = model_db[model_parameters]
model_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(model_db[semiNormal_parameters+nonNormal_parameters]) 
model_db = detect_and_remove_outliers(model_db)
# Out:
# Index(['end_result', 'game', 'game_id', 'period', 'play', 'player', 'playoffs',
#        'score', 'season', 'shot_made', 'time', 'FG%', '2P%', '3P%', 'FT%',
#        'Height', 'Weight', 'draftRank', 'ShootingHand', 'Team', 'Difference',
#        'minute', 'sec', 'abs_min', 'abs_time', 'scores', 'scoreDif', 'Pos_C',
#        'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')

# %%
from keras import backend as K
import tensorflow as tf
# Define our custom loss function
def focal_loss(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.utils import to_categorical
from keras.optimizers import Adagrad
from sklearn import metrics

Y = model_db['shot_made']
X = model_db.drop(columns=['shot_made','player'])

model = Sequential()
model.add(Dense(12, input_dim=X.shape[1]))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(20))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(10))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(5))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss=[focal_loss], optimizer=Adagrad(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X, Y, epochs=100, batch_size=256)
print(metrics.classification_report(Y, np.round(model.predict(X))))
# Out:
# Epoch 1/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 17.2118 - accuracy: 0.4665
# Epoch 2/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.5031 - accuracy: 0.4311
# Epoch 3/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.4047 - accuracy: 0.4402
# Epoch 4/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.3579 - accuracy: 0.4565
# Epoch 5/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.3320 - accuracy: 0.4765
# Epoch 6/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.3064 - accuracy: 0.5077
# Epoch 7/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2929 - accuracy: 0.5451
# Epoch 8/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2876 - accuracy: 0.5761
# Epoch 9/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2723 - accuracy: 0.6003
# Epoch 10/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2664 - accuracy: 0.6151
# Epoch 11/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2649 - accuracy: 0.6281
# Epoch 12/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2546 - accuracy: 0.6383
# Epoch 13/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2511 - accuracy: 0.6453
# Epoch 14/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2454 - accuracy: 0.6508
# Epoch 15/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2444 - accuracy: 0.6569
# Epoch 16/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2412 - accuracy: 0.6606
# Epoch 17/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2346 - accuracy: 0.6645
# Epoch 18/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2320 - accuracy: 0.6660
# Epoch 19/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2358 - accuracy: 0.6692
# Epoch 20/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2330 - accuracy: 0.6715A: 1s -
# Epoch 21/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2289 - accuracy: 0.6733
# Epoch 22/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2276 - accuracy: 0.6760
# Epoch 23/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2190 - accuracy: 0.6758
# Epoch 24/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.2263 - accuracy: 0.6764
# Epoch 25/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2147 - accuracy: 0.6794
# Epoch 26/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2174 - accuracy: 0.6790
# Epoch 27/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2116 - accuracy: 0.6803
# Epoch 28/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2093 - accuracy: 0.6806A: 0s - loss: 16.2119 - accuracy: 0.680
# Epoch 29/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.2128 - accuracy: 0.6795
# Epoch 30/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2083 - accuracy: 0.6807
# Epoch 31/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2075 - accuracy: 0.6806
# Epoch 32/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2062 - accuracy: 0.6803
# Epoch 33/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1994 - accuracy: 0.6813
# Epoch 34/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2031 - accuracy: 0.6804
# Epoch 35/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.2018 - accuracy: 0.6803
# Epoch 36/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.2013 - accuracy: 0.6813
# Epoch 37/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1970 - accuracy: 0.6806
# Epoch 38/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1944 - accuracy: 0.6799
# Epoch 39/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1955 - accuracy: 0.6812
# Epoch 40/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1929 - accuracy: 0.6797
# Epoch 41/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1884 - accuracy: 0.6794
# Epoch 42/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1925 - accuracy: 0.6794
# Epoch 43/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1856 - accuracy: 0.6787
# Epoch 44/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1839 - accuracy: 0.6787
# Epoch 45/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1873 - accuracy: 0.6778
# Epoch 46/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1874 - accuracy: 0.6781A: 0s - loss: 16.1907 - accuracy:
# Epoch 47/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1790 - accuracy: 0.6785
# Epoch 48/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1786 - accuracy: 0.6779A: 0s - loss: 16.1779 - accura
# Epoch 49/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1763 - accuracy: 0.6778
# Epoch 50/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1750 - accuracy: 0.6772
# Epoch 51/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1721 - accuracy: 0.6768
# Epoch 52/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1765 - accuracy: 0.6769
# Epoch 53/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1708 - accuracy: 0.6760
# Epoch 54/100
# 488554/488554 [==============================] - 4s 9us/step - loss: 16.1730 - accuracy: 0.6759
# Epoch 55/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1704 - accuracy: 0.6753
# Epoch 56/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1686 - accuracy: 0.6737
# Epoch 57/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1691 - accuracy: 0.6749
# Epoch 58/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1636 - accuracy: 0.6747A: 1s - loss: 16.1
# Epoch 59/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1681 - accuracy: 0.6740- ETA: 1s - loss: 16.172
# Epoch 60/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1610 - accuracy: 0.6739
# Epoch 61/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1589 - accuracy: 0.6740
# Epoch 62/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1607 - accuracy: 0.6741
# Epoch 63/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1605 - accuracy: 0.6734
# Epoch 64/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1607 - accuracy: 0.6733
# Epoch 65/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1557 - accuracy: 0.6735A: 0s - loss: 16.1611 - accuracy:
# Epoch 66/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1578 - accuracy: 0.6742
# Epoch 67/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1554 - accuracy: 0.6732
# Epoch 68/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1476 - accuracy: 0.6741
# Epoch 69/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1518 - accuracy: 0.6734
# Epoch 70/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1494 - accuracy: 0.6730
# Epoch 71/100
# 488554/488554 [==============================] - 5s 10us/step - loss: 16.1457 - accuracy: 0.6727
# Epoch 72/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1470 - accuracy: 0.6738
# Epoch 73/100
# 488554/488554 [==============================] - 7s 14us/step - loss: 16.1415 - accuracy: 0.6725: 3s - los - ETA: 1s - loss: 16.
# Epoch 74/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1414 - accuracy: 0.6731
# Epoch 75/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1467 - accuracy: 0.6709
# Epoch 76/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1403 - accuracy: 0.6719
# Epoch 77/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1398 - accuracy: 0.6726
# Epoch 78/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 16.1388 - accuracy: 0.6729
# Epoch 79/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1312 - accuracy: 0.6723
# Epoch 80/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1377 - accuracy: 0.6714
# Epoch 81/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1359 - accuracy: 0.6722A: 0s - loss: 16.1448 - accuracy: 0
# Epoch 82/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1357 - accuracy: 0.6719
# Epoch 83/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1373 - accuracy: 0.6709
# Epoch 84/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1321 - accuracy: 0.6715
# Epoch 85/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1221 - accuracy: 0.6716
# Epoch 86/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1242 - accuracy: 0.6716
# Epoch 87/100
# 488554/488554 [==============================] - 3s 5us/step - loss: 16.1329 - accuracy: 0.6715
# Epoch 88/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1207 - accuracy: 0.6719
# Epoch 89/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1252 - accuracy: 0.6718
# Epoch 90/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1227 - accuracy: 0.6715
# Epoch 91/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1193 - accuracy: 0.6722
# Epoch 92/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1210 - accuracy: 0.6712
# Epoch 93/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1163 - accuracy: 0.6725
# Epoch 94/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 16.1095 - accuracy: 0.6724
# Epoch 95/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1165 - accuracy: 0.6706
# Epoch 96/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1135 - accuracy: 0.6713A: 0s - loss: 16.1137 - accuracy
# Epoch 97/100
# 488554/488554 [==============================] - 5s 9us/step - loss: 16.1109 - accuracy: 0.6708
# Epoch 98/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1072 - accuracy: 0.6716
# Epoch 99/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 16.1059 - accuracy: 0.6714
# Epoch 100/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 16.1092 - accuracy: 0.6712
#               precision    recall  f1-score   support
#
#            0       0.31      0.39      0.35    114368
#            1       0.80      0.74      0.77    374186
#
#     accuracy                           0.66    488554
#    macro avg       0.56      0.56      0.56    488554
# weighted avg       0.68      0.66      0.67    488554

# %% [markdown]
# ### Neural Net - binary_crossentropy LOSS
# - Drop NAN
# - Position one-hod encoded
# -  All features standarted to mean=0, std=1
# - Removing Outliers
# - class_weight={0:0.65,1:0.35}

# %%
database_p1 = pd.read_csv("database_preprocessed_part2.csv")
database_p2 = pd.read_csv("database_preprocessed_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
database = database.dropna()

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from preProcess import detect_and_remove_outliers

v = database.player.value_counts()
model_db = database[database.player.isin(v.index[v.gt(200)])]
mm = MinMaxScaler()
sc = StandardScaler()
nonNormal_parameters = ['abs_min', 'draftRank']
semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
onehot_pos_col = pd.get_dummies(model_db['Pos'],prefix='Pos')
model_db = pd.concat([model_db,onehot_pos_col],axis=1)
model_db = model_db.drop(columns=['Pos'])
print(model_db.columns)
model_parameters = ['player','playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
model_db = model_db[model_parameters]
model_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(model_db[semiNormal_parameters+nonNormal_parameters]) 
model_db = detect_and_remove_outliers(model_db)


from keras import backend as K
import tensorflow as tf
# Define our custom loss function
def focal_loss(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.utils import to_categorical
from keras.optimizers import Adagrad
from sklearn import metrics

Y = model_db['shot_made']
X = model_db.drop(columns=['shot_made','player'])

model = Sequential()
model.add(Dense(12, input_dim=X.shape[1]))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(20))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(10))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(5))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss="binary_crossentropy", optimizer=Adagrad(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X, Y, epochs=100, batch_size=256,class_weight={0:0.65,1:0.35})
print(metrics.classification_report(Y, np.round(model.predict(X))))
# Out:
# Index(['end_result', 'game', 'game_id', 'period', 'play', 'player', 'playoffs',
#        'score', 'season', 'shot_made', 'time', 'FG%', '2P%', '3P%', 'FT%',
#        'Height', 'Weight', 'draftRank', 'ShootingHand', 'Team', 'Difference',
#        'minute', 'sec', 'abs_min', 'abs_time', 'scores', 'scoreDif', 'Pos_C',
#        'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')
# Epoch 1/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2881 - accuracy: 0.6421
# Epoch 2/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2803 - accuracy: 0.7422
# Epoch 3/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2782 - accuracy: 0.7554
# Epoch 4/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2770 - accuracy: 0.7602
# Epoch 5/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2763 - accuracy: 0.7618
# Epoch 6/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2756 - accuracy: 0.7625
# Epoch 7/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2752 - accuracy: 0.7630
# Epoch 8/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2750 - accuracy: 0.7628
# Epoch 9/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2746 - accuracy: 0.7632
# Epoch 10/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2743 - accuracy: 0.7629
# Epoch 11/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2739 - accuracy: 0.7625
# Epoch 12/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2739 - accuracy: 0.7625
# Epoch 13/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2734 - accuracy: 0.7624
# Epoch 14/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2733 - accuracy: 0.7618
# Epoch 15/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2731 - accuracy: 0.7616
# Epoch 16/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2729 - accuracy: 0.7612
# Epoch 17/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2729 - accuracy: 0.7611
# Epoch 18/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2727 - accuracy: 0.7606
# Epoch 19/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2724 - accuracy: 0.7607
# Epoch 20/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2725 - accuracy: 0.7605
# Epoch 21/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2723 - accuracy: 0.7600
# Epoch 22/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2722 - accuracy: 0.7597
# Epoch 23/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2720 - accuracy: 0.7600
# Epoch 24/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2719 - accuracy: 0.7597
# Epoch 25/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2718 - accuracy: 0.7598
# Epoch 26/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2717 - accuracy: 0.7594
# Epoch 27/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2717 - accuracy: 0.7592
# Epoch 28/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2717 - accuracy: 0.7588
# Epoch 29/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 0.2714 - accuracy: 0.7587
# Epoch 30/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 0.2715 - accuracy: 0.7588
# Epoch 31/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 0.2714 - accuracy: 0.7586
# Epoch 32/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 0.2712 - accuracy: 0.7590: 0s - loss: 0
# Epoch 33/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2712 - accuracy: 0.7587: 0s - loss: 0.2711 - ac
# Epoch 34/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2713 - accuracy: 0.7582
# Epoch 35/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 0.2712 - accuracy: 0.7579: 0s - loss: 0.2710 -
# Epoch 36/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2712 - accuracy: 0.7576
# Epoch 37/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2711 - accuracy: 0.7579
# Epoch 38/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2711 - accuracy: 0.7583
# Epoch 39/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2710 - accuracy: 0.7577
# Epoch 40/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2710 - accuracy: 0.7574
# Epoch 41/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2707 - accuracy: 0.7577
# Epoch 42/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2710 - accuracy: 0.7569
# Epoch 43/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2708 - accuracy: 0.7572
# Epoch 44/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2707 - accuracy: 0.7572
# Epoch 45/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2706 - accuracy: 0.7574
# Epoch 46/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2707 - accuracy: 0.7570
# Epoch 47/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2705 - accuracy: 0.7570
# Epoch 48/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2705 - accuracy: 0.7567
# Epoch 49/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2705 - accuracy: 0.7567
# Epoch 50/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2705 - accuracy: 0.7566
# Epoch 51/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 0.2705 - accuracy: 0.7563
# Epoch 52/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2703 - accuracy: 0.7568
# Epoch 53/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2704 - accuracy: 0.7567
# Epoch 54/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2703 - accuracy: 0.7563
# Epoch 55/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2703 - accuracy: 0.7561
# Epoch 56/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2703 - accuracy: 0.7563
# Epoch 57/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2702 - accuracy: 0.7563
# Epoch 58/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2702 - accuracy: 0.7561
# Epoch 59/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2700 - accuracy: 0.7561
# Epoch 60/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2701 - accuracy: 0.7556
# Epoch 61/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2701 - accuracy: 0.7562
# Epoch 62/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2700 - accuracy: 0.7560
# Epoch 63/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2701 - accuracy: 0.7557
# Epoch 64/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2700 - accuracy: 0.7559
# Epoch 65/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2700 - accuracy: 0.7555
# Epoch 66/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2700 - accuracy: 0.7553
# Epoch 67/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2699 - accuracy: 0.7553
# Epoch 68/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 0.2698 - accuracy: 0.7556
# Epoch 69/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2698 - accuracy: 0.7557
# Epoch 70/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2698 - accuracy: 0.7551
# Epoch 71/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2699 - accuracy: 0.7552
# Epoch 72/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2699 - accuracy: 0.7547
# Epoch 73/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2698 - accuracy: 0.7555
# Epoch 74/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2697 - accuracy: 0.7549
# Epoch 75/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2698 - accuracy: 0.7546
# Epoch 76/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2698 - accuracy: 0.7552
# Epoch 77/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2697 - accuracy: 0.7552
# Epoch 78/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7549
# Epoch 79/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2697 - accuracy: 0.7546
# Epoch 80/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7545
# Epoch 81/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7549
# Epoch 82/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7546
# Epoch 83/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7546
# Epoch 84/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7549: 0s - loss: 0.2695 - accuracy:
# Epoch 85/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7546
# Epoch 86/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2694 - accuracy: 0.7545
# Epoch 87/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2696 - accuracy: 0.7541
# Epoch 88/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7541
# Epoch 89/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7541
# Epoch 90/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7541
# Epoch 91/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7543
# Epoch 92/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7539
# Epoch 93/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2695 - accuracy: 0.7536
# Epoch 94/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2694 - accuracy: 0.7542
# Epoch 95/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2694 - accuracy: 0.7536
# Epoch 96/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2694 - accuracy: 0.7540
# Epoch 97/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2693 - accuracy: 0.7541
# Epoch 98/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2694 - accuracy: 0.7539
# Epoch 99/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2693 - accuracy: 0.7538
# Epoch 100/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 0.2692 - accuracy: 0.7542
#               precision    recall  f1-score   support
#
#            0       0.44      0.06      0.10    114368
#            1       0.77      0.98      0.86    374186
#
#     accuracy                           0.76    488554
#    macro avg       0.61      0.52      0.48    488554
# weighted avg       0.70      0.76      0.68    488554

# %% [markdown]
# ### Neural Net - FOCAL LOSS
# - Drop NAN
# - Position one-hod encoded
# -  All features standarted to mean=0, std=1
# - Removing Outliers
# - class_weight={0:0.65,1:0.35}

# %%
database_p1 = pd.read_csv("database_preprocessed_part2.csv")
database_p2 = pd.read_csv("database_preprocessed_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
database = database.dropna()

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from preProcess import detect_and_remove_outliers

v = database.player.value_counts()
model_db = database[database.player.isin(v.index[v.gt(200)])]
mm = MinMaxScaler()
sc = StandardScaler()
nonNormal_parameters = ['abs_min', 'draftRank']
semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
onehot_pos_col = pd.get_dummies(model_db['Pos'],prefix='Pos')
model_db = pd.concat([model_db,onehot_pos_col],axis=1)
model_db = model_db.drop(columns=['Pos'])
print(model_db.columns)
model_parameters = ['player','playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
model_db = model_db[model_parameters]
model_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(model_db[semiNormal_parameters+nonNormal_parameters]) 
model_db = detect_and_remove_outliers(model_db)


from keras import backend as K
import tensorflow as tf
# Define our custom loss function
def focal_loss(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.utils import to_categorical
from keras.optimizers import Adagrad
from sklearn import metrics

Y = model_db['shot_made']
X = model_db.drop(columns=['shot_made','player'])

model = Sequential()
model.add(Dense(12, input_dim=X.shape[1]))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(20))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(10))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(5))#, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss=[focal_loss], optimizer=Adagrad(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X, Y, epochs=100, batch_size=256,class_weight={0:0.65,1:0.35})
print(metrics.classification_report(Y, np.round(model.predict(X))))
# Out:
# Index(['end_result', 'game', 'game_id', 'period', 'play', 'player', 'playoffs',
#        'score', 'season', 'shot_made', 'time', 'FG%', '2P%', '3P%', 'FT%',
#        'Height', 'Weight', 'draftRank', 'ShootingHand', 'Team', 'Difference',
#        'minute', 'sec', 'abs_min', 'abs_time', 'scores', 'scoreDif', 'Pos_C',
#        'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')
# Epoch 1/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 7.0993 - accuracy: 0.5788: 0s - loss: 7.1037 - accuracy: 0.
# Epoch 2/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.8757 - accuracy: 0.6629
# Epoch 3/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.8457 - accuracy: 0.6779
# Epoch 4/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.8325 - accuracy: 0.6847
# Epoch 5/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.8227 - accuracy: 0.6873
# Epoch 6/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.8154 - accuracy: 0.6911
# Epoch 7/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.8101 - accuracy: 0.6914
# Epoch 8/100
# 488554/488554 [==============================] - 4s 9us/step - loss: 6.8078 - accuracy: 0.6937: 0s - loss: 6.8086 - accura
# Epoch 9/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.8011 - accuracy: 0.6942
# Epoch 10/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7968 - accuracy: 0.6958
# Epoch 11/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7954 - accuracy: 0.6963
# Epoch 12/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7935 - accuracy: 0.6972
# Epoch 13/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7912 - accuracy: 0.6975
# Epoch 14/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7883 - accuracy: 0.6981
# Epoch 15/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7848 - accuracy: 0.6986
# Epoch 16/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7862 - accuracy: 0.6983
# Epoch 17/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7833 - accuracy: 0.6981
# Epoch 18/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7820 - accuracy: 0.6980
# Epoch 19/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7833 - accuracy: 0.6978
# Epoch 20/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7805 - accuracy: 0.6980
# Epoch 21/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7773 - accuracy: 0.6992: 0s - loss:
# Epoch 22/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7767 - accuracy: 0.6986
# Epoch 23/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7762 - accuracy: 0.6981
# Epoch 24/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7750 - accuracy: 0.6982
# Epoch 25/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7739 - accuracy: 0.6980
# Epoch 26/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7747 - accuracy: 0.6979
# Epoch 27/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7697 - accuracy: 0.6984
# Epoch 28/100
# 488554/488554 [==============================] - 4s 9us/step - loss: 6.7686 - accuracy: 0.6980
# Epoch 29/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7686 - accuracy: 0.6978
# Epoch 30/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7679 - accuracy: 0.6972
# Epoch 31/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7694 - accuracy: 0.6971
# Epoch 32/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7654 - accuracy: 0.6976
# Epoch 33/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7633 - accuracy: 0.6975
# Epoch 34/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7656 - accuracy: 0.6968
# Epoch 35/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7630 - accuracy: 0.6961
# Epoch 36/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7626 - accuracy: 0.6955
# Epoch 37/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7622 - accuracy: 0.6957
# Epoch 38/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7631 - accuracy: 0.6949
# Epoch 39/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7617 - accuracy: 0.6944
# Epoch 40/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7579 - accuracy: 0.6955: 0s - loss: 6.7586 -
# Epoch 41/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7588 - accuracy: 0.6942
# Epoch 42/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7591 - accuracy: 0.6937
# Epoch 43/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7573 - accuracy: 0.6940
# Epoch 44/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7566 - accuracy: 0.6936
# Epoch 45/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7543 - accuracy: 0.6927
# Epoch 46/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7550 - accuracy: 0.6926
# Epoch 47/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7521 - accuracy: 0.6924
# Epoch 48/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7530 - accuracy: 0.6920
# Epoch 49/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7536 - accuracy: 0.6913
# Epoch 50/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7512 - accuracy: 0.6918
# Epoch 51/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7478 - accuracy: 0.6915
# Epoch 52/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7496 - accuracy: 0.6911
# Epoch 53/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7487 - accuracy: 0.6900
# Epoch 54/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7485 - accuracy: 0.6905
# Epoch 55/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7438 - accuracy: 0.6904
# Epoch 56/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7471 - accuracy: 0.6892
# Epoch 57/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7442 - accuracy: 0.6897
# Epoch 58/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7447 - accuracy: 0.6892
# Epoch 59/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7447 - accuracy: 0.6877
# Epoch 60/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7420 - accuracy: 0.6883
# Epoch 61/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7440 - accuracy: 0.6876
# Epoch 62/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7439 - accuracy: 0.6870
# Epoch 63/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7419 - accuracy: 0.6866
# Epoch 64/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7423 - accuracy: 0.6865
# Epoch 65/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7399 - accuracy: 0.6870
# Epoch 66/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7367 - accuracy: 0.6866
# Epoch 67/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7397 - accuracy: 0.6849
# Epoch 68/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7380 - accuracy: 0.6857
# Epoch 69/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7396 - accuracy: 0.6851
# Epoch 70/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7398 - accuracy: 0.6841
# Epoch 71/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7366 - accuracy: 0.6839
# Epoch 72/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7349 - accuracy: 0.6839
# Epoch 73/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7368 - accuracy: 0.6837
# Epoch 74/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7332 - accuracy: 0.6839
# Epoch 75/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7364 - accuracy: 0.6830
# Epoch 76/100
# 488554/488554 [==============================] - 5s 11us/step - loss: 6.7367 - accuracy: 0.6823
# Epoch 77/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7343 - accuracy: 0.6829
# Epoch 78/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7339 - accuracy: 0.6826
# Epoch 79/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7335 - accuracy: 0.6823
# Epoch 80/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7313 - accuracy: 0.6816
# Epoch 81/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7311 - accuracy: 0.6813
# Epoch 82/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7317 - accuracy: 0.6813
# Epoch 83/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7318 - accuracy: 0.6806
# Epoch 84/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7295 - accuracy: 0.6816
# Epoch 85/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7306 - accuracy: 0.6802
# Epoch 86/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7287 - accuracy: 0.6802
# Epoch 87/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7323 - accuracy: 0.6787
# Epoch 88/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7260 - accuracy: 0.6803
# Epoch 89/100
# 488554/488554 [==============================] - 3s 6us/step - loss: 6.7273 - accuracy: 0.6791
# Epoch 90/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7273 - accuracy: 0.6787
# Epoch 91/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7289 - accuracy: 0.6782
# Epoch 92/100
# 488554/488554 [==============================] - 5s 10us/step - loss: 6.7289 - accuracy: 0.6779
# Epoch 93/100
# 488554/488554 [==============================] - 5s 10us/step - loss: 6.7262 - accuracy: 0.6779
# Epoch 94/100
# 488554/488554 [==============================] - 4s 9us/step - loss: 6.7249 - accuracy: 0.6784
# Epoch 95/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7241 - accuracy: 0.6778
# Epoch 96/100
# 488554/488554 [==============================] - 4s 9us/step - loss: 6.7259 - accuracy: 0.6772
# Epoch 97/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7261 - accuracy: 0.6767
# Epoch 98/100
# 488554/488554 [==============================] - 3s 7us/step - loss: 6.7255 - accuracy: 0.6778
# Epoch 99/100
# 488554/488554 [==============================] - 4s 8us/step - loss: 6.7233 - accuracy: 0.6769
# Epoch 100/100
# 488554/488554 [==============================] - 4s 7us/step - loss: 6.7243 - accuracy: 0.6760
#               precision    recall  f1-score   support
#
#            0       0.36      0.26      0.30    114368
#            1       0.79      0.86      0.82    374186
#
#     accuracy                           0.72    488554
#    macro avg       0.57      0.56      0.56    488554
# weighted avg       0.69      0.72      0.70    488554

# %% [markdown]
# ### PCA to 2D - trying to visualize

# %%
database_p1 = pd.read_csv("database_preprocessed_part2.csv")
database_p2 = pd.read_csv("database_preprocessed_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
database = database.dropna()

database_p1 = pd.read_csv("database_preprocessed_part2.csv")
database_p2 = pd.read_csv("database_preprocessed_part2.csv")
database = pd.concat([database_p1,database_p2])
database = database.drop(columns=['Unnamed: 0', 'Unnamed: 0'])
database = database.dropna()

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from preProcess import detect_and_remove_outliers,run_PCA

v = database.player.value_counts()
model_db = database[database.player.isin(v.index[v.gt(200)])]
mm = MinMaxScaler()
sc = StandardScaler()
nonNormal_parameters = ['abs_min', 'draftRank']
semiNormal_parameters = ['FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'Difference']
onehot_pos_col = pd.get_dummies(model_db['Pos'],prefix='Pos')
model_db = pd.concat([model_db,onehot_pos_col],axis=1)
model_db = model_db.drop(columns=['Pos'])
print(model_db.columns)
model_parameters = ['player','playoffs', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG', 'ShootingHand', 'FG%', '2P%', '3P%', 'FT%', 'Height', 'Weight', 'draftRank','abs_min', 'Difference','shot_made']
model_db = model_db[model_parameters]
model_db[semiNormal_parameters+nonNormal_parameters] = sc.fit_transform(model_db[semiNormal_parameters+nonNormal_parameters]) 
model_db = detect_and_remove_outliers(model_db)

Y = model_db['shot_made']
X = model_db.drop(columns=['shot_made','player'])
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
print(principalDf.shape)
print(model_db[['shot_made']].shape)

#finalDf = pd.concat([ principalDf, model_db[['shot_made']] ], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0, 1]
colors = ['r', 'b']

rows = principalDf.shape[0]
for i in range(10000):
    if Y[i:i+1].values[0] == 0:
        color = 'r'
    else:
        color = 'b'
    pc1,pc2 = principalDf[i:i+1]['principal component 1'].values[0], principalDf[i:i+1]['principal component 2'].values[0]
    ax.scatter(pc1
               , pc2
               , c = color
               , s = 50)
    if i%1000 == 0:
        print(i)

ax.legend(targets)
ax.grid()
# for target, color in zip(targets,colors):
#     indicesToKeep = finalDf['shot_made'] == target
#     ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
#                , finalDf.loc[indicesToKeep, 'principal component 2']
#                , c = color
#                , s = 50)
# ax.legend(targets)
# ax.grid()
# Out:
# Index(['end_result', 'game', 'game_id', 'period', 'play', 'player', 'playoffs',
#        'score', 'season', 'shot_made', 'time', 'FG%', '2P%', '3P%', 'FT%',
#        'Height', 'Weight', 'draftRank', 'ShootingHand', 'Team', 'Difference',
#        'minute', 'sec', 'abs_min', 'abs_time', 'scores', 'scoreDif', 'Pos_C',
#        'Pos_PF', 'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')
# (488554, 2)
# (488554, 1)
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
